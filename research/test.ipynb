# %% [markdown]
# # Data Ingestion Module

# %%
import os
# %pwd
# Out:
# 'c:\\Users\\uNUKE\\OneDrive\\Documents\\DSML\\text-summarizer\\research'

# %%
os.chdir('../')
# %pwd
# Out:
# 'c:\\Users\\uNUKE\\OneDrive\\Documents\\DSML\\text-summarizer'
